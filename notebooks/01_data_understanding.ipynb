# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/kashakjoshi/Desktop/Telco Customer Churn/data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/kashakjoshi/Desktop/Telco Customer Churn/notebooks'

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %% [markdown]
# ### Category Level Audit

# %%
df.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='str')

# %%
df.select_dtypes(include=['object']).columns
# Out:
# /var/folders/wn/g5_hm17x5bs75fqy7c1h_htr0000gn/T/ipykernel_1538/549554427.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include=['object']).columns
# Index(['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges',
#        'Churn'],
#       dtype='str')

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(f"\n{col}")
    print(df[col].unique())
# Out:
# customerID
# <StringArray>
# ['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', '7795-CFOCW', '9237-HQITU',
#  '9305-CDSKC', '1452-KIOVK', '6713-OKOMC', '7892-POOKP', '6388-TABGU',
#  ...
#  '9767-FFLEM', '0639-TSIQW', '8456-QDAVC', '7750-EYXWZ', '2569-WGERO',
#  '6840-RESVB', '2234-XADUH', '4801-JZAZL', '8361-LTMKD', '3186-AJIEK']
# Length: 7043, dtype: str
#
# gender
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#
# Partner
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
#
# Dependents
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# PhoneService
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# MultipleLines
# <StringArray>
# ['No phone service', 'No', 'Yes']
# Length: 3, dtype: str
#
# InternetService
# <StringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str
#
# OnlineSecurity
# <StringArray>
# ['No', 'Yes', 'No internet service']
# Length: 3, dtype: str
#
# OnlineBackup
# <StringArray>
# ['Yes', 'No', 'No internet service']
# ...

# %% [markdown]
# ### High-Impact Columns

# %%
print("InternetService:", df["InternetService"].unique())
print("Contract:", df["Contract"].unique())
print("PaymentMethod:", df["PaymentMethod"].unique())
print("TotalCharges sample:", df["TotalCharges"].head())
# Out:
# InternetService: <StringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str
# Contract: <StringArray>
# ['Month-to-month', 'One year', 'Two year']
# Length: 3, dtype: str
# PaymentMethod: <StringArray>
# [         'Electronic check',              'Mailed check',
#  'Bank transfer (automatic)',   'Credit card (automatic)']
# Length: 4, dtype: str
# TotalCharges sample: 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# Name: TotalCharges, dtype: str

# %%
df["TotalCharges"].describe()
# Out:
# count     7043
# unique    6531
# top       20.2
# freq        11
# Name: TotalCharges, dtype: object

# %%
(df["TotalCharges"] == " ").sum()
# Out:
# np.int64(11)

# %%
df[df["TotalCharges"] == " "][["tenure", "MonthlyCharges"]]
# Out:
#       tenure  MonthlyCharges
# 488        0           52.55
# 753        0           20.25
# 936        0           80.85
# 1082       0           25.75
# 1340       0           56.05
# 3331       0           19.85
# 3826       0           25.35
# 4380       0           20.00
# 5218       0           19.70
# 6670       0           73.35
# 6754       0           61.90

# %% [markdown]
# ### Numeric Feature Statistical Overview

# %%
df[["tenure", "MonthlyCharges"]].describe()
# Out:
#             tenure  MonthlyCharges
# count  7043.000000     7043.000000
# mean     32.371149       64.761692
# std      24.559481       30.090047
# min       0.000000       18.250000
# 25%       9.000000       35.500000
# 50%      29.000000       70.350000
# 75%      55.000000       89.850000
# max      72.000000      118.750000

# %%
df[df["tenure"] == 0].shape
# Out:
# (11, 21)

# %%
df[df["MonthlyCharges"] == 0].shape
# Out:
# (0, 21)

# %% [markdown]
# ### Duplicate Check

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ###  Handling Blank Values in TotalCharges

# %%
# Replace blank strings with 0
df["TotalCharges"] = df["TotalCharges"].replace(" ", 0)

# %%
(df["TotalCharges"] == " ").sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Converting TotalCharges to Numeric Type

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"])

# %%
df["TotalCharges"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Converting SeniorCitizen to Categorical Type

# %%
df["SeniorCitizen"] = df["SeniorCitizen"].astype("category")

# %%
df["SeniorCitizen"].dtype
# Out:
# CategoricalDtype(categories=[0, 1], ordered=False, categories_dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   category
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7043.000000
# mean     32.371149       64.761692   2279.734304
# std      24.559481       30.090047   2266.794470
# min       0.000000       18.250000      0.000000
# 25%       9.000000       35.500000    398.550000
# 50%      29.000000       70.350000   1394.550000
# 75%      55.000000       89.850000   3786.600000
# max      72.000000      118.750000   8684.800000

# %%
import os
os.getcwd()
# Out:
# '/Users/kashakjoshi/Desktop/Telco Customer Churn/notebooks'

# %%
df.to_csv("../data/processed/telco_cleaned.csv", index=False)
